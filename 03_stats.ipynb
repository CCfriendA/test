# %% [markdown]
# # Pandas统计计算和描述

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# * 常用的统计计算

# %%
df_obj = pd.DataFrame(np.random.randn(5,4), columns = ['a', 'b', 'c', 'd'])
df_obj
# Out:
#           a         b         c         d
# 0 -0.519207  0.527466 -0.886064  0.499334
# 1  0.055417  0.426955 -1.929524 -0.186610
# 2 -0.405316 -2.022038  0.171688  0.873419
# 3 -1.961590 -0.954387 -2.197822 -1.395204
# 4  0.172559  0.217600  1.177543  0.029251

# %%
df_obj.sum()
# Out:
# a   -2.658137
# b   -1.804404
# c   -3.664179
# d   -0.179809
# dtype: float64

# %%
df_obj.max()

# %%
df_obj.min(axis=1)
# Out:
# 0   -0.886064
# 1   -1.929524
# 2   -2.022038
# 3   -2.197822
# 4    0.029251
# dtype: float64

# %% [markdown]
# * 统计描述

# %%
df_obj.describe()
# Out:
#               a         b         c         d
# count  5.000000  5.000000  5.000000  5.000000
# mean  -0.235960  0.116849 -0.091286  0.974063
# std    0.813846  0.810310  1.691682  0.695273
# min   -1.029492 -1.079358 -2.571532 -0.137338
# 25%   -0.851403 -0.097063 -0.249523  0.887987
# 50%   -0.425933  0.032874 -0.092689  1.029167
# 75%    0.159467  0.748722  0.283668  1.412111
# max    0.967561  0.979070  2.173644  1.678388
