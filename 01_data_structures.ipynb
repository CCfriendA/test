# %% [markdown]
# # Pandas数据结构

# %%
import pandas as pd

# %% [markdown]
# * Series

# %%
# 通过list构建Series
ser_obj = pd.Series(range(10, 20))
print(type(ser_obj))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# 获取数据
print(type(ser_obj.values))

# 获取索引
print(type(ser_obj.index))
# Out:
# <class 'numpy.ndarray'>
# <class 'pandas.indexes.range.RangeIndex'>

# %%
# 预览数据
print(ser_obj.head(6))
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# 4    14
# 5    15
# dtype: int32

# %%
print(ser_obj)

# %%
#通过索引获取数据
print(ser_obj[0])
print(ser_obj[8])
# Out:
# 10
# 18

# %%
# 索引与数据的对应关系仍保持在数组运算的结果中
#print(ser_obj * 2)
print(ser_obj[ser_obj > 15])
# Out:
# 6    16
# 7    17
# 8    18
# 9    19
# dtype: int32

# %%
# 通过dict构建Series
year_data = {600000: 17.8, 600310: 20.1, 600432: 16.5}
ser_obj2 = pd.Series(year_data)
print(ser_obj2.head())
print(ser_obj2.index)
# Out:
# 600000    17.8
# 600310    20.1
# 600432    16.5
# dtype: float64
# Int64Index([600000, 600310, 600432], dtype='int64')

# %%
# name属性
ser_obj2.name = 'temp'
ser_obj2.index.name = 'year'
print(ser_obj2.head())
# Out:
# year
# 600000    17.8
# 600310    20.1
# 600432    16.5
# Name: temp, dtype: float64

# %% [markdown]
# * DataFrame

# %%
import numpy as np

# 通过ndarray构建DataFrame
array = np.random.randn(5,4)
# print(array)
df_obj = pd.DataFrame(array)
print(df_obj.head())
# Out:
#           0         1         2         3
# 0 -2.055860 -0.450926  0.776758  2.454551
# 1 -0.749034 -1.549061  0.042596 -0.783043
# 2  0.498744  0.203092 -1.094794 -1.548947
# 3 -0.592500 -1.251152  0.672631 -1.392328
# 4  0.349078 -1.419199  1.466921  0.259883

# %%
# 通过dict构建DataFrame
dict_data = {'A': 1., 
             'B': pd.Timestamp('20161217'),
             'C': pd.Series(1, index=list(range(4)),dtype='float32'),
             'D': np.array([3] * 4,dtype='int32'),
             'E' : pd.Categorical(["Python","Java","C++","C#"]),
             'F' : 'ChinaHadoop' }
#print dict_data
df_obj2 = pd.DataFrame(dict_data)
print(df_obj2.head())
# Out:
#      A          B    C  D       E            F
# 0  1.0 2016-12-17  1.0  3  Python  ChinaHadoop
# 1  1.0 2016-12-17  1.0  3    Java  ChinaHadoop
# 2  1.0 2016-12-17  1.0  3     C++  ChinaHadoop
# 3  1.0 2016-12-17  1.0  3      C#  ChinaHadoop

# %%
# 通过列索引获取列数据
print(df_obj2['A'])
print(type(df_obj2['A']))

print(df_obj2.A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-b8e13417e186> in <module>()
#       1 # 通过列索引获取列数据
# ----> 2 print(df_obj2['A'])
#       3 print(type(df_obj2['A']))
#       4
#       5 print(df_obj2.A)
#
# NameError: name 'df_obj2' is not defined

# %%
# 增加列
df_obj2['J'] = df_obj2['D'] + 10
print(df_obj2.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-ec3fa820bf02> in <module>()
#       1 # 增加列
# ----> 2 df_obj2['G'] = df_obj2['D'] + 10
#       3 print(df_obj2.head())
#
# NameError: name 'df_obj2' is not defined

# %%
# 删除列
del(df_obj2['G'] )
print(df_obj2.head())

# %% [markdown]
# * 索引对象 Index

# %%
print(type(ser_obj.index))
print(type(df_obj2.index))

print(df_obj2.index)

# %%
# 索引对象不可变
df_obj2.index[0] = 2
